# %% [markdown]
# # Conflict Prediction

# %% [markdown]
# In this project our aim was to predict and analyse early signs of brewing tension. We used data from the global economy. We selected social, political, and economic factors to look at.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

url = 'https://raw.githubusercontent.com/chekirou/International-conflict-prediction/master/data/actual.csv'

# %%
df = pd.read_csv(url)

# %%
csv1 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv1.csv')
csv2 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv2.csv')
csv3 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv3.csv')
csv4 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv4.csv')
csv5 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv5.csv')
csv6 = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/old_datasets/csv6.csv')
csv_pov = pd.read_csv('/Users/yasmeenmahomedy2/code/yasmeeenm/conflict_analysis/other peoples notebooks/poverty_df.csv')

# %%
csv1['CountryYear'] = csv1['Country']+csv1['Year'].astype(str)
csv2['CountryYear'] = csv2['Country']+csv2['Year'].astype(str)
csv3['CountryYear'] = csv3['Country']+csv3['Year'].astype(str)
csv4['CountryYear'] = csv4['Country']+csv4['Year'].astype(str)
csv5['CountryYear'] = csv5['Country']+csv5['Year'].astype(str)
csv6['CountryYear'] = csv6['Country']+csv6['Year'].astype(str)

# %%
csv_12 = pd.merge(csv1,csv2,on='CountryYear',how='outer')
csv_123 = pd.merge(csv_12,csv3,on='CountryYear',how='outer')
csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
csv_12345 = pd.merge(csv_1234,csv5,on='CountryYear',how='outer')
csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')

csv_full
# Out:
# /var/folders/ty/xzkrlw3n681fsxzmh9cl7wq00000gq/T/ipykernel_74067/3997445115.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Code_x', 'Year_x', 'ContinentCode_x', 'Country_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_1234 = pd.merge(csv_123,csv4,on='CountryYear',how='outer')
# /var/folders/ty/xzkrlw3n681fsxzmh9cl7wq00000gq/T/ipykernel_74067/3997445115.py:5: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Code_x', 'Year_x', 'ContinentCode_x', 'Country_x'} in the result is deprecated and will raise a MergeError in a future version.
#   csv_full = pd.merge(csv_12345,csv6,on='CountryYear',how='outer')
#          Country_x Code_x ContinentCode_x  Year_x  \
# 0      Afghanistan    AFG              AS  1960.0
# 1      Afghanistan    AFG              AS  1961.0
# 2      Afghanistan    AFG              AS  1962.0
# 3      Afghanistan    AFG              AS  1963.0
# 4      Afghanistan    AFG              AS  1964.0
# ...            ...    ...             ...     ...
# 12559          NaN    NaN             NaN     NaN
# 12560          NaN    NaN             NaN     NaN
# 12561          NaN    NaN             NaN     NaN
# 12562          NaN    NaN             NaN     NaN
# 12563          NaN    NaN             NaN     NaN
#
#        Military spending percent of total government spending   \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                NaN
#
#        Arms imports million constant U.S. dollars  \
# 0                                            40.0
# 1                                            56.0
# 2                                            64.0
# 3                                            40.0
# 4                                            56.0
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         NaN
#
#        Cost of living index world average = 100  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 12559                                       NaN
# 12560                                       NaN
# 12561                                       NaN
# 12562                                       NaN
# 12563                                       NaN
#
#        Food price index world average = 100  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 12559                                   NaN
# 12560                                   NaN
# 12561                                   NaN
# 12562                                   NaN
# 12563                                   NaN
#
#        Housing and utilities price index world average  = 100  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                NaN
#
#        Healthcare price index world average = 100  ...  \
# 0                                             NaN  ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4                                             NaN  ...
# ...                                           ...  ...
# 12559                                         NaN  ...
# 12560                                         NaN  ...
# 12561                                         NaN  ...
# 12562                                         NaN  ...
# 12563                                         NaN  ...
#
#        Security threats index 0 (low) - 10 (high)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 12559                                         NaN
# 12560                                         NaN
# 12561                                         NaN
# 12562                                         NaN
# 12563                                         9.1
#
#        Factionalized elites index 0 (low) - 10 (high)  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 12559                                             NaN
# 12560                                             NaN
# 12561                                             NaN
# 12562                                             NaN
# 12563                                            10.0
#
#       Group grievance index 0 (low) - 10 (high)  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 12559                                       NaN
# 12560                                       NaN
# 12561                                       NaN
# 12562                                       NaN
# 12563                                       9.1
#
#       Economic decline index 0 (low) - 10 (high)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 12559                                        NaN
# 12560                                        NaN
# 12561                                        NaN
# 12562                                        NaN
# 12563                                        9.9
#
#       Uneven economic development index 0 (low) - 10 (high)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                8.0
#
#       State legitimacy index 0 (high) - 10 (low)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 12559                                        NaN
# 12560                                        NaN
# 12561                                        NaN
# 12562                                        NaN
# 12563                                        9.9
#
#        Human rights and rule of law index 0 (high) - 10 (low)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                9.9
#
#        Demographic pressures 0 (low) - 10 (high)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 12559                                        NaN
# 12560                                        NaN
# 12561                                        NaN
# 12562                                        NaN
# 12563                                        9.9
#
#        Refugees and displaced persons index 0 (low) - 10 (high)  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 12559                                                NaN
# 12560                                                NaN
# 12561                                                NaN
# 12562                                                NaN
# 12563                                                9.9
#
#        External interventions index 0 (low) - 10 (high)
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 12559                                               NaN
# 12560                                               NaN
# 12561                                               NaN
# 12562                                               NaN
# 12563                                               9.4
#
# [12564 rows x 114 columns]

# %%
conflicts = pd.read_csv('/Users/yasmeenmahomedy2/Downloads/civil_war_dataset - Combined, from 1970.csv')

# %%
def get_year(row):
    
    year_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
def get_country(row):
    
    country_name = row['CountryYear'][:-4]

    return country_name

# %%
csv_full['year_all'] = csv_full.apply(lambda x: get_year(x),axis=1)

# %%
csv_full['country_all'] = csv_full.apply(lambda x: get_country(x), axis=1)

# %% [markdown]
# # Refining The Dataset

# %% [markdown]
# Here we remove smaller countries with insufficient data.

# %%
tiny_countries = ['Andorra','Antigua and Barbuda','Aruba','Belize','Bhutan','Brunei','Cape Verde','Comoros','Dominica','Kiribati',
                 'Micronesia','Montserrat','Palau','Saint Vincent and the Grenadines','Sao Tome and Principe','Solomon Islands','Taiwan',
                  'Tuvalu','Vanuatu','Euro area','Faroe Islands','Gibraltar','Macao','New Caledonia','San Marino','Norfolk Island','Holy See (Vatican City)']
csv_full = csv_full.set_index('country_all').drop(tiny_countries)
csv_full.reset_index(inplace=True)

# %%
csv_full['conflict_id'] =0
conflicts

csv_full[(csv_full['country_all']=='USA') & (csv_full['year_all']>1994)]

conflicts_1990 = conflicts[conflicts['Year']>1989]

# %%
my_list = []

def get_hist_data(country,year,lookback):
    
    early_year = lookback
    hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    while hist_data.shape[0] < lookback:
        early_year += 1
        
        hist_data = csv_full[(csv_full['country_all']==country) & (csv_full['year_all'] <= (year -1)) & (csv_full['year_all'] > (year -1 - early_year))]
    return hist_data

for index, row in conflicts_1990.iterrows():

    my_list.append(get_hist_data(row['Country'],row['Year'],5))


get_hist_data('USA',2010,10)    
    
len(my_list)
# Out:
# 94

# %%
for i in range(len(my_list)):
    my_list[i]['conflict_id'] = i
# Out:
# /var/folders/ty/xzkrlw3n681fsxzmh9cl7wq00000gq/T/ipykernel_74067/729059741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   my_list[i]['conflict_id'] = i

# %%
for i in range(len(my_list)):
    if len(my_list[i]) < 5:
        print(i)

# %%
final_df = pd.DataFrame(columns=my_list[50].columns)

# %%
for i in range(len(my_list)):
    
    final_df = pd.concat([final_df,my_list[i]])

# %%
final_df.shape
# Out:
# (470, 117)

# %% [markdown]
# # Dropping features

# %% [markdown]
# We drop features with 70% or more of the data missisng.

# %%
final_df.shape
# Out:
# (470, 117)

# %%
to_drop  = pd.DataFrame(final_df.isna().sum()/470)
len(to_drop)
# Out:
# 117

# %%
to_drop_list = to_drop[to_drop[0]>0.7].index.values.tolist()
len(to_drop_list)
# Out:
# 26

# %%
for i in to_drop_list:
    final_df.drop(columns=i, axis=1, inplace=True)

# %%
# final_df['CountryYear']

# %% [markdown]
# ## Dropping data for the imputer

# %% [markdown]
# We will use an iterative imputer to fill in the remaining missing data.

# %%
bin_list = []
final_df
# Out:
#      country_all   Country_x Code_x ContinentCode_x  Year_x  \
# 6348      Rwanda      Rwanda    RWA              AF  1985.0
# 6349      Rwanda      Rwanda    RWA              AF  1986.0
# 6350      Rwanda      Rwanda    RWA              AF  1988.0
# 9657      Rwanda         NaN    NaN             NaN     NaN
# 9658      Rwanda         NaN    NaN             NaN     NaN
# ...          ...         ...    ...             ...     ...
# 3938  Kazakhstan  Kazakhstan    KAZ              AS  2017.0
# 3939  Kazakhstan  Kazakhstan    KAZ              AS  2018.0
# 3940  Kazakhstan  Kazakhstan    KAZ              AS  2019.0
# 3941  Kazakhstan  Kazakhstan    KAZ              AS  2020.0
# 3942  Kazakhstan  Kazakhstan    KAZ              AS  2021.0
#
#       Military spending percent of total government spending   \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                               3.45
# 3939                                               4.65
# 3940                                               5.25
# 3941                                               4.56
# 3942                                                NaN
#
#       Arms imports million constant U.S. dollars  \
# 6348                                         3.0
# 6349                                         2.0
# 6350                                         2.0
# 9657                                         NaN
# 9658                                         NaN
# ...                                          ...
# 3938                                       214.0
# 3939                                       310.0
# 3940                                       312.0
# 3941                                       268.0
# 3942                                         NaN
#
#       Human Development Index (0 - 1)     CountryYear   Country_y  ...  \
# 6348                              NaN      Rwanda1985      Rwanda  ...
# 6349                              NaN      Rwanda1986      Rwanda  ...
# 6350                              NaN      Rwanda1988      Rwanda  ...
# 9657                              NaN      Rwanda1987      Rwanda  ...
# 9658                              NaN      Rwanda1989      Rwanda  ...
# ...                               ...             ...         ...  ...
# 3938                            0.813  Kazakhstan2017  Kazakhstan  ...
# 3939                            0.817  Kazakhstan2018  Kazakhstan  ...
# 3940                            0.817  Kazakhstan2019  Kazakhstan  ...
# 3941                            0.825  Kazakhstan2020  Kazakhstan  ...
# 3942                              NaN  Kazakhstan2021  Kazakhstan  ...
#
#      Group grievance index 0 (low) - 10 (high)  \
# 6348                                       NaN
# 6349                                       NaN
# 6350                                       NaN
# 9657                                       NaN
# 9658                                       NaN
# ...                                        ...
# 3938                                       7.6
# 3939                                       7.9
# 3940                                       8.1
# 3941                                       8.2
# 3942                                       8.0
#
#      Economic decline index 0 (low) - 10 (high)  \
# 6348                                        NaN
# 6349                                        NaN
# 6350                                        NaN
# 9657                                        NaN
# 9658                                        NaN
# ...                                         ...
# 3938                                        6.4
# 3939                                        5.9
# 3940                                        5.6
# 3941                                        5.3
# 3942                                        5.5
#
#       Uneven economic development index 0 (low) - 10 (high)  \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                                4.2
# 3939                                                3.9
# 3940                                                3.6
# 3941                                                3.3
# 3942                                                3.2
#
#       State legitimacy index 0 (high) - 10 (low)  \
# 6348                                         NaN
# 6349                                         NaN
# 6350                                         NaN
# 9657                                         NaN
# 9658                                         NaN
# ...                                          ...
# 3938                                         8.3
# 3939                                         8.4
# 3940                                         8.5
# 3941                                         8.5
# 3942                                         8.2
#
#       Human rights and rule of law index 0 (high) - 10 (low)  \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                                7.3
# 3939                                                7.0
# 3940                                                6.7
# 3941                                                6.4
# 3942                                                6.7
#
#       Demographic pressures 0 (low) - 10 (high)  \
# 6348                                        NaN
# 6349                                        NaN
# 6350                                        NaN
# 9657                                        NaN
# 9658                                        NaN
# ...                                         ...
# 3938                                        4.5
# 3939                                        4.2
# 3940                                        3.9
# 3941                                        3.6
# 3942                                        4.1
#
#       Refugees and displaced persons index 0 (low) - 10 (high)  \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                                3.0
# 3939                                                2.7
# 3940                                                2.4
# 3941                                                2.3
# 3942                                                2.1
#
#       External interventions index 0 (low) - 10 (high)  year_all  conflict_id
# 6348                                               NaN      1985            0
# 6349                                               NaN      1986            0
# 6350                                               NaN      1988            0
# 9657                                               NaN      1987            0
# 9658                                               NaN      1989            0
# ...                                                ...       ...          ...
# 3938                                               4.2      2017           93
# 3939                                               3.9      2018           93
# 3940                                               3.6      2019           93
# 3941                                               3.3      2020           93
# 3942                                               3.0      2021           93
#
# [470 rows x 91 columns]

# %%
cleaner_df = final_df.drop(columns=bin_list)

# %%
cleaner_1985 = cleaner_df[cleaner_df['year_all']>1984]

imputer_drops = ['Country_x','Code_x','Country_y','Year_x','Year_y','Code_y','ContinentCode_y','ContinentCode_x','Christians as percent of the total population',
            'Shadow economy percent of GDP','Suicide mortality rate per 100000 population',
                 'Real interest rate: Bank lending rate minus inflation','Fiscal balance percent of GDP',
                 'Public spending on education percent of GDP','Government debt as percent of GDP',
                 'External debt percent of Gross National Income', 'GDP per capita Purchasing Power Parity',
                 'Banking system z-scores',
             'Factionalized elites index 0 (low) - 10 (high)', 'Security threats index 0 (low) - 10 (high)',
            'Economic decline index 0 (low) - 10 (high)','Human rights and rule of law index 0 (high) - 10 (low)',
            'External interventions index 0 (low) - 10 (high)',  'Uneven economic development index 0 (low) - 10 (high)',
            'State legitimacy index 0 (high) - 10 (low)',
            'Refugees and displaced persons index 0 (low) - 10 (high)', 'Demographic pressures 0 (low) - 10 (high)',
            'Refugee population',
             'Regulatory quality index (-2.5 weak; 2.5 strong)', 'Voice and accountability index (-2.5 weak; 2.5 strong)',
            'Military spending percent of total government spending ', 'Arms imports million constant U.S. dollars',
                
            'Capital investment as percent of GDP', 'Youth unemployment ages 15-24',
           'Food production index (2004-2006 = 100)', 'Foreign Direct Investment percent of GDP',
           'Population size in millions', 'Rural population percent of total population',
           'Population growth percent','Deaths of children under five years of age per 1000 live births',
            'Life expectancy in years',
            'Internet users percent of population',
           'Civil liberties index 7 (weak) - 1 (strong) ',
           'Globalization index (0-100)', 'Political globalization index (0-100)',
              'Labor freedom index (0-100)',
            'Economic freedom overall index (0-100)', 'Freedom from corruption index (0-100)',
               'Government spending as percent of GDP', 'Income from natural resources percent of GDP',
              'Human Development Index (0 - 1)', 'Inflation: percent change in the Consumer Price Index',
               'GDP per capita current U.S. dollars', 'Foreign aid and official development assistance received',
                'Unemployment rate',
#                  'Government effectiveness index (-2.5 weak; 2.5 strong)', 'Homicides per 100000 people', 'Death rate per 1000 people'
                 
                ]

# %%
cleaner_df = cleaner_df.drop(columns=imputer_drops)

# %%
(cleaner_1985.isna().sum()/cleaner_1985.shape[0]).sort_values()[40:60]
# Out:
# GDP per capita current U.S. dollars                         0.082979
# Economic globalization index (0-100)                        0.095745
# ContinentCode_x                                             0.097872
# Foreign Direct Investment percent of GDP                    0.102128
# Income from natural resources percent of GDP                0.102128
# Refugee population                                          0.117021
# Foreign aid and official development assistance received    0.123404
# Labor force participation rate                              0.129787
# Trade balance as percent of GDP                             0.148936
# Inflation: percent change in the Consumer Price Index       0.148936
# Internet users percent of population                        0.151064
# Trade openness: exports plus imports as percent of GDP      0.155319
# Unemployment rate                                           0.157447
# Youth unemployment ages 15-24                               0.157447
# Capital investment as percent of GDP                        0.165957
# Human Development Index (0 - 1)                             0.172340
# Government spending as percent of GDP                       0.189362
# GDP per capita Purchasing Power Parity                      0.223404
# External debt percent of Gross National Income              0.234043
# Access to electricity percent of the population             0.287234
# dtype: float64

# %%
cleaner_df['conflict_id']=cleaner_df['conflict_id'].astype(int)

# %%
cleaner_df
# Out:
#      country_all     CountryYear  \
# 6348      Rwanda      Rwanda1985
# 6349      Rwanda      Rwanda1986
# 6350      Rwanda      Rwanda1988
# 9657      Rwanda      Rwanda1987
# 9658      Rwanda      Rwanda1989
# ...          ...             ...
# 3938  Kazakhstan  Kazakhstan2017
# 3939  Kazakhstan  Kazakhstan2018
# 3940  Kazakhstan  Kazakhstan2019
# 3941  Kazakhstan  Kazakhstan2020
# 3942  Kazakhstan  Kazakhstan2021
#
#       Economic growth: the rate of change of real GDP  \
# 6348                                             4.40
# 6349                                             5.47
# 6350                                             4.50
# 9657                                            -0.02
# 9658                                            -0.04
# ...                                               ...
# 3938                                             4.10
# 3939                                             4.10
# 3940                                             4.50
# 3941                                            -2.50
# 3942                                             4.00
#
#       Labor force participation rate  \
# 6348                             NaN
# 6349                             NaN
# 6350                             NaN
# 9657                             NaN
# 9658                             NaN
# ...                              ...
# 3938                           69.25
# 3939                           70.13
# 3940                           70.08
# 3941                           69.20
# 3942                           69.07
#
#       Trade openness: exports plus imports as percent of GDP  \
# 6348                                              30.67
# 6349                                              32.74
# 6350                                              24.22
# 9657                                              26.59
# 9658                                              23.43
# ...                                                 ...
# 3938                                              56.83
# 3939                                              63.53
# 3940                                              64.86
# 3941                                              56.22
# 3942                                                NaN
#
#       Trade balance as percent of GDP  \
# 6348                            -9.10
# 6349                            -7.57
# 6350                           -10.98
# 9657                           -11.69
# 9658                           -11.15
# ...                               ...
# 3938                             7.97
# 3939                            11.72
# 3940                             8.02
# 3941                             4.23
# 3942                              NaN
#
#       Rule of law index (-2.5 weak; 2.5 strong)  \
# 6348                                        NaN
# 6349                                        NaN
# 6350                                        NaN
# 9657                                        NaN
# 9658                                        NaN
# ...                                         ...
# 3938                                      -0.47
# 3939                                      -0.49
# 3940                                      -0.49
# 3941                                      -0.44
# 3942                                      -0.49
#
#       Government effectiveness index (-2.5 weak; 2.5 strong)  \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                              -0.03
# 3939                                              -0.01
# 3940                                               0.11
# 3941                                               0.14
# 3942                                               0.06
#
#       Control of corruption (-2.5 weak; 2.5 strong)  \
# 6348                                            NaN
# 6349                                            NaN
# 6350                                            NaN
# 9657                                            NaN
# 9658                                            NaN
# ...                                             ...
# 3938                                          -0.82
# 3939                                          -0.47
# 3940                                          -0.26
# 3941                                          -0.36
# 3942                                          -0.24
#
#       Political stability index (-2.5 weak; 2.5 strong)  \
# 6348                                                NaN
# 6349                                                NaN
# 6350                                                NaN
# 9657                                                NaN
# 9658                                                NaN
# ...                                                 ...
# 3938                                               0.03
# 3939                                              -0.05
# 3940                                              -0.17
# 3941                                              -0.26
# 3942                                              -0.25
#
#       Corruption Perceptions Index 100 = no corruption  \
# 6348                                               NaN
# 6349                                               NaN
# 6350                                               NaN
# 9657                                               NaN
# 9658                                               NaN
# ...                                                ...
# 3938                                              31.0
# 3939                                              31.0
# 3940                                              34.0
# 3941                                              38.0
# 3942                                              37.0
#
#       Political rights index 7 (weak) - 1 (strong)  \
# 6348                                           NaN
# 6349                                           NaN
# 6350                                           NaN
# 9657                                           NaN
# 9658                                           NaN
# ...                                            ...
# 3938                                           7.0
# 3939                                           7.0
# 3940                                           7.0
# 3941                                           7.0
# 3942                                           NaN
#
#       Access to electricity percent of the population  \
# 6348                                              NaN
# 6349                                              NaN
# 6350                                              NaN
# 9657                                              NaN
# 9658                                              NaN
# ...                                               ...
# 3938                                            100.0
# 3939                                            100.0
# 3940                                            100.0
# 3941                                            100.0
# 3942                                              NaN
#
#       Death rate per 1000 people  Economic globalization index (0-100)  \
# 6348                       14.05                                 19.89
# 6349                       15.48                                 21.05
# 6350                       23.00                                 19.88
# 9657                       18.52                                 20.75
# 9658                       28.54                                 18.82
# ...                          ...                                   ...
# 3938                        7.15                                 52.59
# 3939                        7.14                                 52.96
# 3940                        7.19                                 56.25
# 3941                        8.60                                   NaN
# 3942                         NaN                                   NaN
#
#       Social globalization index (0-100)  Homicides per 100000 people  \
# 6348                               14.37                          NaN
# 6349                               14.53                          NaN
# 6350                               15.68                          NaN
# 9657                               15.15                          NaN
# 9658                               15.76                          NaN
# ...                                  ...                          ...
# 3938                               69.83                          5.0
# 3939                               68.69                          NaN
# 3940                               66.51                          NaN
# 3941                                 NaN                          NaN
# 3942                                 NaN                          NaN
#
#       Group grievance index 0 (low) - 10 (high) year_all  conflict_id
# 6348                                        NaN     1985            0
# 6349                                        NaN     1986            0
# 6350                                        NaN     1988            0
# 9657                                        NaN     1987            0
# 9658                                        NaN     1989            0
# ...                                         ...      ...          ...
# 3938                                        7.6     2017           93
# 3939                                        7.9     2018           93
# 3940                                        8.1     2019           93
# 3941                                        8.2     2020           93
# 3942                                        8.0     2021           93
#
# [470 rows x 20 columns]

# %% [markdown]
# # Grouping the data

# %% [markdown]
# Group data by conflict ID

# %%
grouped_df = cleaner_df.groupby(by='conflict_id').mean()
# Out:
# /var/folders/ty/xzkrlw3n681fsxzmh9cl7wq00000gq/T/ipykernel_74067/2490057627.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   grouped_df = cleaner_df.groupby(by='conflict_id').mean()

# %%
grouped_df.columns
# Out:
# Index(['Economic growth: the rate of change of real GDP',
#        'Labor force participation rate',
#        'Trade openness: exports plus imports as percent of GDP',
#        'Trade balance as percent of GDP',
#        'Rule of law index (-2.5 weak; 2.5 strong)',
#        'Government effectiveness index (-2.5 weak; 2.5 strong)',
#        'Control of corruption (-2.5 weak; 2.5 strong)',
#        'Political stability index (-2.5 weak; 2.5 strong)',
#        'Corruption Perceptions Index 100 = no corruption',
#        'Political rights index 7 (weak) - 1 (strong)',
#        'Access to electricity percent of the population',
#        'Death rate per 1000 people', 'Economic globalization index (0-100)',
#        'Social globalization index (0-100)', 'Homicides per 100000 people',
#        'Group grievance index 0 (low) - 10 (high)'],
#       dtype='object')

# %% [markdown]
# # Create the control dataset

# %%
conflict_years = final_df['CountryYear']

# %%
csv4_after_1980 = csv_full[csv_full['year_all'] > 1985]
csv4_after_1980_noconflict = csv4_after_1980[csv4_after_1980.CountryYear.isin(conflict_years)==False]
csv4_after_1980.shape[0] - csv4_after_1980_noconflict.shape[0]
# Out:
# 437

# %%
def slice_fn(sample):
    year = int(sample[-4:])
    words = [sample[:-4]+str(year-i-1) for i in range(4)]
    words.append(sample)
    return words

# %%
#change for sara

from itertools import chain

sample_list = []

control_sample = csv4_after_1980.sample(270,random_state=1776)

for index,row in control_sample.iterrows():
    sample_list.append(get_hist_data(row['country_all'],row['year_all'],5))

sample_full = sample_list[0]

for i in range(1,len(sample_list)):
    
    sample_full = pd.concat([sample_full,sample_list[i]])

# %%
id_list = list(range(95,365))*5
sample_full
# Out:
#      country_all   Country_x Code_x ContinentCode_x  Year_x  \
# 3217     Hungary     Hungary    HUN              EU  2011.0
# 3218     Hungary     Hungary    HUN              EU  2012.0
# 3219     Hungary     Hungary    HUN              EU  2013.0
# 3220     Hungary     Hungary    HUN              EU  2014.0
# 3221     Hungary     Hungary    HUN              EU  2015.0
# ...          ...         ...    ...             ...     ...
# 554   Bangladesh  Bangladesh    BGD              AS  1985.0
# 555   Bangladesh  Bangladesh    BGD              AS  1986.0
# 556   Bangladesh  Bangladesh    BGD              AS  1987.0
# 557   Bangladesh  Bangladesh    BGD              AS  1988.0
# 558   Bangladesh  Bangladesh    BGD              AS  1989.0
#
#       Military spending percent of total government spending   \
# 3217                                               2.11
# 3218                                               2.09
# 3219                                               1.88
# 3220                                               1.71
# 3221                                               1.80
# ...                                                 ...
# 554                                                 NaN
# 555                                                 NaN
# 556                                                 NaN
# 557                                               10.33
# 558                                               10.45
#
#       Arms imports million constant U.S. dollars  \
# 3217                                         9.0
# 3218                                         NaN
# 3219                                         2.0
# 3220                                         7.0
# 3221                                         NaN
# ...                                          ...
# 554                                         63.0
# 555                                          4.0
# 556                                          1.0
# 557                                        242.0
# 558                                        301.0
#
#       Cost of living index world average = 100  \
# 3217                                       NaN
# 3218                                       NaN
# 3219                                       NaN
# 3220                                       NaN
# 3221                                       NaN
# ...                                        ...
# 554                                        NaN
# 555                                        NaN
# 556                                        NaN
# 557                                        NaN
# 558                                        NaN
#
#       Food price index world average = 100  \
# 3217                                   NaN
# 3218                                   NaN
# 3219                                   NaN
# 3220                                   NaN
# 3221                                   NaN
# ...                                    ...
# 554                                    NaN
# 555                                    NaN
# 556                                    NaN
# 557                                    NaN
# 558                                    NaN
#
#       Housing and utilities price index world average  = 100  ...  \
# 3217                                                NaN       ...
# 3218                                                NaN       ...
# 3219                                                NaN       ...
# 3220                                                NaN       ...
# 3221                                                NaN       ...
# ...                                                 ...       ...
# 554                                                 NaN       ...
# 555                                                 NaN       ...
# 556                                                 NaN       ...
# 557                                                 NaN       ...
# 558                                                 NaN       ...
#
#       Group grievance index 0 (low) - 10 (high)  \
# 3217                                        3.5
# 3218                                        3.8
# 3219                                        4.1
# 3220                                        4.4
# 3221                                        4.7
# ...                                         ...
# 554                                         NaN
# 555                                         NaN
# 556                                         NaN
# 557                                         NaN
# 558                                         NaN
#
#       Economic decline index 0 (low) - 10 (high)  \
# 3217                                         5.4
# 3218                                         5.9
# 3219                                         6.0
# 3220                                         5.6
# 3221                                         5.9
# ...                                          ...
# 554                                          NaN
# 555                                          NaN
# 556                                          NaN
# 557                                          NaN
# 558                                          NaN
#
#       Uneven economic development index 0 (low) - 10 (high)  \
# 3217                                                5.5
# 3218                                                5.2
# 3219                                                4.9
# 3220                                                4.6
# 3221                                                4.3
# ...                                                 ...
# 554                                                 NaN
# 555                                                 NaN
# 556                                                 NaN
# 557                                                 NaN
# 558                                                 NaN
#
#      State legitimacy index 0 (high) - 10 (low)  \
# 3217                                        5.4
# 3218                                        5.8
# 3219                                        5.9
# 3220                                        6.0
# 3221                                        6.6
# ...                                         ...
# 554                                         NaN
# 555                                         NaN
# 556                                         NaN
# 557                                         NaN
# 558                                         NaN
#
#      Human rights and rule of law index 0 (high) - 10 (low)  \
# 3217                                                3.0
# 3218                                                3.2
# 3219                                                3.4
# 3220                                                4.1
# 3221                                                4.5
# ...                                                 ...
# 554                                                 NaN
# 555                                                 NaN
# 556                                                 NaN
# 557                                                 NaN
# 558                                                 NaN
#
#      Demographic pressures 0 (low) - 10 (high)  \
# 3217                                       3.1
# 3218                                       2.8
# 3219                                       2.5
# 3220                                       2.8
# 3221                                       2.3
# ...                                        ...
# 554                                        NaN
# 555                                        NaN
# 556                                        NaN
# 557                                        NaN
# 558                                        NaN
#
#      Refugees and displaced persons index 0 (low) - 10 (high)  \
# 3217                                                3.1
# 3218                                                2.8
# 3219                                                2.9
# 3220                                                2.8
# 3221                                                2.5
# ...                                                 ...
# 554                                                 NaN
# 555                                                 NaN
# 556                                                 NaN
# 557                                                 NaN
# 558                                                 NaN
#
#       External interventions index 0 (low) - 10 (high)  year_all  conflict_id
# 3217                                               4.3      2011            0
# 3218                                               4.0      2012            0
# 3219                                               3.8      2013            0
# 3220                                               3.7      2014            0
# 3221                                               4.0      2015            0
# ...                                                ...       ...          ...
# 554                                                NaN      1985            0
# 555                                                NaN      1986            0
# 556                                                NaN      1987            0
# 557                                                NaN      1988            0
# 558                                                NaN      1989            0
#
# [1350 rows x 117 columns]

# %%
id_list = sorted(id_list)

# %%
sample_full['conflict_id'] = id_list
sample_full['country_all'].unique()
# Out:
# array(['Hungary', 'Slovenia', 'Kenya', 'Rwanda', 'Puerto Rico',
#        'Botswana', 'Tonga', 'Angola', 'Mauritius', 'Turkey', 'France',
#        'Tanzania', 'Sweden', 'Oman', 'Greece', 'Bahamas', 'Ireland',
#        'Lebanon', 'Guatemala', 'Turkmenistan', 'Estonia', 'Lesotho',
#        'Malta', 'Nepal', 'Luxembourg', 'Iraq', 'Honduras', 'Bahrain',
#        'Morocco', 'Egypt', 'Moldova', 'Tajikistan', 'Afghanistan',
#        'Central African Republic', 'Democratic Republic of the Congo',
#        'Swaziland', 'Jamaica', 'North Macedonia', 'Equatorial Guinea',
#        'Uzbekistan', 'Azerbaijan', 'Mozambique', 'Senegal', 'Italy',
#        'Saint Lucia', 'Suriname', 'Costa Rica', 'Mexico', 'Maldives',
#        'Nigeria', 'Uruguay', 'United Arab Emirates', 'Ukraine',
#        'Palestine', 'Sierra Leone', 'Zambia', 'Hong Kong', 'Germany',
#        'Poland', 'Brazil', 'Syria', 'Jordan', 'Lithuania', 'Argentina',
#        'Guinea-Bissau', 'Namibia', 'Ghana', 'Somalia', 'Serbia',
#        'North Korea', 'Cuba', 'Dominican Republic', 'Venezuela', 'Benin',
#        'Yemen', 'Gambia', 'Norway', 'Gabon', 'Colombia', 'Samoa',
#        'Cyprus', 'Mali', 'USA', 'Liberia', 'Papua New Guinea',
#        'Kyrgyzstan', 'Niger', 'Finland', 'Bermuda', 'Portugal',
#        'Pakistan', 'Armenia', 'Madagascar', 'Sri Lanka', 'Monaco',
#        'Latvia', 'Kuwait', 'Guyana', 'Libya', 'South Africa',
#        'Liechtenstein', 'Belgium', 'Croatia', 'Seychelles', 'Togo',
#        'Zimbabwe', 'Iran', 'Netherlands', 'Ivory Coast', 'Indonesia',
#        'Uganda', 'Russia', 'South Korea', 'Austria', 'Switzerland',
#        'Denmark', 'India', 'Belarus', 'Burkina Faso', 'Fiji',
#        'Kazakhstan', 'Burundi', 'Bosnia and Herzegovina', 'Israel',
#        'United Kingdom', 'Djibouti', 'Eritrea', 'Algeria', 'Ecuador',
#        'Ethiopia', 'Cambodia', 'Qatar', 'Czechia', 'Barbados', 'Japan',
#        'New Zealand', 'Paraguay', 'Malaysia', 'Iceland', 'Saudi Arabia',
#        'El Salvador', 'Bolivia', 'Chad', 'Vietnam', 'Nicaragua',
#        'Bangladesh'], dtype=object)

# %%
control_groupedby = sample_full.groupby('conflict_id').mean()
control_groupedby
# Out:
# /var/folders/ty/xzkrlw3n681fsxzmh9cl7wq00000gq/T/ipykernel_74067/2170563677.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   control_groupedby = sample_full.groupby('conflict_id').mean()
#              Year_x  Military spending percent of total government spending   \
# conflict_id
# 95           2013.0                                              1.918
# 96           1998.0                                              2.882
# 97           2002.0                                              6.804
# 98           1984.0                                                NaN
# 99              NaN                                                NaN
# ...             ...                                                ...
# 360          2016.0                                              4.100
# 361          2007.0                                              6.150
# 362          2016.0                                              4.240
# 363          2017.0                                             14.004
# 364          1987.0                                             10.390
#
#              Arms imports million constant U.S. dollars  \
# conflict_id
# 95                                             6.000000
# 96                                            10.600000
# 97                                            12.000000
# 98                                             4.333333
# 99                                                  NaN
# ...                                                 ...
# 360                                           20.250000
# 361                                            9.200000
# 362                                           10.500000
# 363                                          582.200000
# 364                                          122.200000
#
#              Cost of living index world average = 100  \
# conflict_id
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
# ...                                               ...
# 360                                             53.79
# 361                                               NaN
# 362                                             73.82
# 363                                            167.52
# 364                                               NaN
#
#              Food price index world average = 100  \
# conflict_id
# 95                                            NaN
# 96                                            NaN
# 97                                            NaN
# 98                                            NaN
# 99                                            NaN
# ...                                           ...
# 360                                        68.300
# 361                                           NaN
# 362                                        86.250
# 363                                       171.324
# 364                                           NaN
#
#              Housing and utilities price index world average  = 100  \
# conflict_id
# 95                                                         NaN
# 96                                                         NaN
# 97                                                         NaN
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                     35.969
# 361                                                        NaN
# 362                                                     72.933
# 363                                                    232.165
# 364                                                        NaN
#
#              Healthcare price index world average = 100  \
# conflict_id
# 95                                                  NaN
# 96                                                  NaN
# 97                                                  NaN
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                               48.48
# 361                                                 NaN
# 362                                               59.68
# 363                                              186.30
# 364                                                 NaN
#
#              Happiness Index 0 (unhappy) - 10 (happy)  \
# conflict_id
# 95                                             4.7900
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
# ...                                               ...
# 360                                            5.8200
# 361                                               NaN
# 362                                            6.0925
# 363                                            7.2180
# 364                                               NaN
#
#              Human Development Index (0 - 1)  Year_y  ...  \
# conflict_id                                           ...
# 95                                    0.8304  2013.0  ...
# 96                                    0.8064  1998.0  ...
# 97                                    0.4566  2002.0  ...
# 98                                       NaN  1983.0  ...
# 99                                       NaN  1984.0  ...
# ...                                      ...     ...  ...
# 360                                   0.6916  2016.0  ...
# 361                                   0.4482  2007.0  ...
# 362                                   0.6628  2016.0  ...
# 363                                   0.9038  2017.0  ...
# 364                                      NaN  1987.0  ...
#
#              Factionalized elites index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                 4.880000
# 96                                                      NaN
# 97                                                      NaN
# 98                                                      NaN
# 99                                                      NaN
# ...                                                     ...
# 360                                                8.060000
# 361                                                3.933333
# 362                                                4.300000
# 363                                                8.100000
# 364                                                     NaN
#
#              Group grievance index 0 (low) - 10 (high)  \
# conflict_id
# 95                                            4.100000
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                           6.240000
# 361                                           5.833333
# 362                                           6.320000
# 363                                           9.900000
# 364                                                NaN
#
#              Economic decline index 0 (low) - 10 (high)  \
# conflict_id
# 95                                             5.760000
# 96                                                  NaN
# 97                                                  NaN
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                            5.440000
# 361                                            6.066667
# 362                                            5.680000
# 363                                            4.000000
# 364                                                 NaN
#
#              Uneven economic development index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                    4.900000
# 96                                                         NaN
# 97                                                         NaN
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                   8.580000
# 361                                                   7.166667
# 362                                                   6.520000
# 363                                                   6.680000
# 364                                                        NaN
#
#              State legitimacy index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                 5.94
# 96                                                  NaN
# 97                                                  NaN
# 98                                                  NaN
# 99                                                  NaN
# ...                                                 ...
# 360                                                6.80
# 361                                                5.80
# 362                                                4.94
# 363                                                6.40
# 364                                                 NaN
#
#              Human rights and rule of law index 0 (high) - 10 (low)  \
# conflict_id
# 95                                                    3.640000
# 96                                                         NaN
# 97                                                         NaN
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                   6.020000
# 361                                                   5.866667
# 362                                                   6.140000
# 363                                                   7.340000
# 364                                                        NaN
#
#              Demographic pressures 0 (low) - 10 (high)  \
# conflict_id
# 95                                            2.700000
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                           6.460000
# 361                                           7.133333
# 362                                           6.880000
# 363                                           5.760000
# 364                                                NaN
#
#              Refugees and displaced persons index 0 (low) - 10 (high)  \
# conflict_id
# 95                                                    2.820000
# 96                                                         NaN
# 97                                                         NaN
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                   3.960000
# 361                                                   5.333333
# 362                                                   5.060000
# 363                                                   7.380000
# 364                                                        NaN
#
#              External interventions index 0 (low) - 10 (high)  year_all
# conflict_id
# 95                                                   3.960000    2013.0
# 96                                                        NaN    1998.0
# 97                                                        NaN    2002.0
# 98                                                        NaN    1983.0
# 99                                                        NaN    1984.0
# ...                                                       ...       ...
# 360                                                  5.960000    2016.0
# 361                                                  5.566667    2007.0
# 362                                                  5.560000    2016.0
# 363                                                  7.620000    2017.0
# 364                                                       NaN    1987.0
#
# [270 rows x 96 columns]

# %%
columns_to_keep = list(grouped_df.columns)

# %%
sample_full_clean = control_groupedby.drop(columns=[col for col in control_groupedby if col not in columns_to_keep])

# sample_full_clean.isna().sum()

sample_full_clean
# Out:
#              Economic growth: the rate of change of real GDP  \
# conflict_id
# 95                                                     2.066
# 96                                                     4.106
# 97                                                     2.592
# 98                                                     2.678
# 99                                                     2.022
# ...                                                      ...
# 360                                                    4.600
# 361                                                    3.184
# 362                                                    2.268
# 363                                                    3.774
# 364                                                    3.308
#
#              Labor force participation rate  \
# conflict_id
# 95                                   52.592
# 96                                   58.144
# 97                                   72.750
# 98                                      NaN
# 99                                      NaN
# ...                                     ...
# 360                                  69.248
# 361                                  49.402
# 362                                  58.552
# 363                                  63.932
# 364                                     NaN
#
#              Trade openness: exports plus imports as percent of GDP  \
# conflict_id
# 95                                                     166.372
# 96                                                      96.588
# 97                                                      55.608
# 98                                                      32.518
# 99                                                      99.982
# ...                                                        ...
# 360                                                     64.680
# 361                                                     56.676
# 362                                                     75.482
# 363                                                     58.274
# 364                                                     17.588
#
#              Trade balance as percent of GDP  \
# conflict_id
# 95                                     6.376
# 96                                    -2.418
# 97                                    -7.562
# 98                                    -9.968
# 99                                     1.846
# ...                                      ...
# 360                                   -4.868
# 361                                  -16.734
# 362                                  -17.300
# 363                                    1.976
# 364                                   -6.974
#
#              Rule of law index (-2.5 weak; 2.5 strong)  \
# conflict_id
# 95                                            0.572000
# 96                                            1.073333
# 97                                           -0.917500
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                          -1.174000
# 361                                          -0.220000
# 362                                          -0.718000
# 363                                           1.054000
# 364                                                NaN
#
#              Government effectiveness index (-2.5 weak; 2.5 strong)  \
# conflict_id
# 95                                                       0.622
# 96                                                       0.770
# 97                                                      -0.700
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                     -0.498
# 361                                                     -0.376
# 362                                                     -0.290
# 363                                                      1.324
# 364                                                        NaN
#
#              Control of corruption (-2.5 weak; 2.5 strong)  \
# conflict_id
# 95                                                0.246000
# 96                                                1.033333
# 97                                               -1.000000
# 98                                                     NaN
# 99                                                     NaN
# ...                                                    ...
# 360                                              -0.684000
# 361                                              -0.382000
# 362                                              -0.478000
# 363                                               0.904000
# 364                                                    NaN
#
#              Political stability index (-2.5 weak; 2.5 strong)  \
# conflict_id
# 95                                                    0.728000
# 96                                                    1.146667
# 97                                                   -1.152500
# 98                                                         NaN
# 99                                                         NaN
# ...                                                        ...
# 360                                                  -0.284000
# 361                                                  -0.212000
# 362                                                  -0.158000
# 363                                                  -0.894000
# 364                                                        NaN
#
#              Corruption Perceptions Index 100 = no corruption  \
# conflict_id
# 95                                                      52.00
# 96                                                        NaN
# 97                                                      19.75
# 98                                                        NaN
# 99                                                        NaN
# ...                                                       ...
# 360                                                     32.80
# 361                                                     33.00
# 362                                                     36.40
# 363                                                     61.60
# 364                                                       NaN
#
#              Political rights index 7 (weak) - 1 (strong)  \
# conflict_id
# 95                                                    1.4
# 96                                                    1.0
# 97                                                    4.4
# 98                                                    NaN
# 99                                                    NaN
# ...                                                   ...
# 360                                                   3.0
# 361                                                   2.4
# 362                                                   2.0
# 363                                                   1.2
# 364                                                   4.2
#
#              Access to electricity percent of the population  \
# conflict_id
# 95                                                   100.000
# 96                                                   100.000
# 97                                                    17.958
# 98                                                       NaN
# 99                                                       NaN
# ...                                                      ...
# 360                                                   91.592
# 361                                                   49.766
# 362                                                   96.066
# 363                                                  100.000
# 364                                                      NaN
#
#              Death rate per 1000 people  Economic globalization index (0-100)  \
# conflict_id
# 95                               12.980                                83.286
# 96                                9.460                                56.742
# 97                               12.054                                42.778
# 98                               15.056                                21.210
# 99                                6.780                                   NaN
# ...                                 ...                                   ...
# 360                               6.852                                45.460
# 361                               8.374                                44.210
# 362                               6.984                                61.596
# 363                               5.160                                70.414
# 364                              11.662                                19.638
#
#              Social globalization index (0-100)  Homicides per 100000 people  \
# conflict_id
# 95                                       80.662                     1.640000
# 96                                       71.360                     1.500000
# 97                                       29.306                     3.400000
# 98                                       14.446                          NaN
# 99                                       54.868                          NaN
# ...                                         ...                          ...
# 360                                      59.208                     7.166667
# 361                                      46.212                          NaN
# 362                                      64.112                    78.175000
# 363                                      86.004                     1.400000
# 364                                      12.956                          NaN
#
#              Group grievance index 0 (low) - 10 (high)
# conflict_id
# 95                                            4.100000
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# ...                                                ...
# 360                                           6.240000
# 361                                           5.833333
# 362                                           6.320000
# 363                                           9.900000
# 364                                                NaN
#
# [270 rows x 16 columns]

# %%
# sample_full_clean

# sara_conflict = pd.read_csv('imputed_final_df.csv',index_col=0)
# sara_control = pd.read_csv('imputed_control.csv')


# test_sara_conflict_ali_control = pd.concat([sara_conflict,imputed_control_df])
# test_sara_control_ali_conflict = pd.concat([imputed_conflict_df,sara_control])

# %% [markdown]
# # Merging dataset and imputing all

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

imputer = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)
imputer2 = IterativeImputer(max_iter=10, random_state=0, missing_values=np.nan)

grouped_df['target'] = 1
sample_full_clean['target'] = 0

numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']


full_dataset = pd.concat([grouped_df,sample_full_clean])

# %%
data_numeric = full_dataset.select_dtypes(include=numerics)

imputer.fit(data_numeric)
imputed_final_df = pd.DataFrame(imputer.transform(data_numeric),columns=full_dataset.columns)
imputed_final_df.head()
# Out:
# /Users/yasmeenmahomedy2/.pyenv/versions/3.10.6/envs/conflict_prediction/lib/python3.10/site-packages/sklearn/impute/_iterative.py:713: ConvergenceWarning: [IterativeImputer] Early stopping criterion not reached.
#   warnings.warn(
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.862
# 1                                            3.200
# 2                                            3.308
# 3                                            4.888
# 4                                           -4.666
#
#    Labor force participation rate  \
# 0                       68.268783
# 1                       65.447974
# 2                       64.137536
# 3                       65.709782
# 4                       65.840000
#
#    Trade openness: exports plus imports as percent of GDP  \
# 0                                             27.530
# 1                                             44.086
# 2                                             17.588
# 3                                             32.680
# 4                                             85.330
#
#    Trade balance as percent of GDP  Rule of law index (-2.5 weak; 2.5 strong)  \
# 0                          -10.098                                  -1.371218
# 1                          -11.674                                  -0.755741
# 2                           -6.974                                  -1.120072
# 3                           -9.670                                  -1.022976
# 4                           -2.880                                  -0.242828
#
#    Government effectiveness index (-2.5 weak; 2.5 strong)  \
# 0                                          -1.313885
# 1                                          -0.862529
# 2                                          -1.200600
# 3                                          -1.136050
# 4                                          -0.196360
#
#    Control of corruption (-2.5 weak; 2.5 strong)  \
# 0                                      -0.997020
# 1                                      -0.723355
# 2                                      -1.004051
# 3                                      -0.887328
# 4                                      -0.202176
#
#    Political stability index (-2.5 weak; 2.5 strong)  \
# 0                                          -1.440434
# 1                                          -1.206879
# 2                                          -1.552569
# 3                                          -1.321218
# 4                                          -0.746951
#
#    Corruption Perceptions Index 100 = no corruption  \
# 0                                         21.181396
# 1                                         27.744979
# 2                                         21.854781
# 3                                         22.897702
# 4                                         42.586463
#
#    Political rights index 7 (weak) - 1 (strong)  \
# 0                                      5.249038
# 1                                      3.200000
# 2                                      4.200000
# 3                                      3.200000
# 4                                      3.823515
#
#    Access to electricity percent of the population  \
# 0                                         3.415823
# 1                                        26.963813
# 2                                        20.475494
# 3                                        13.449053
# 4                                        64.591686
#
#    Death rate per 1000 people  Economic globalization index (0-100)  \
# 0                      19.918                             20.078000
# 1                      12.480                             36.974000
# 2                      11.662                             19.638000
# 3                      14.434                             17.994000
# 4                       9.238                             53.553034
#
#    Social globalization index (0-100)  Homicides per 100000 people  \
# 0                           15.098000                     6.511650
# 1                           21.962000                     6.665634
# 2                           12.956000                     6.980996
# 3                           12.112000                     6.497581
# 4                           56.010697                     5.000000
#
#    Group grievance index 0 (low) - 10 (high)  target
# 0                                   7.776382     1.0
# 1                                   7.079117     1.0
# 2                                   7.808531     1.0
# 3                                   7.460993     1.0
# 4                                   6.400380     1.0

# %%
imputed_final_df.describe()
# Out:
#        Economic growth: the rate of change of real GDP  \
# count                                       364.000000
# mean                                          3.623288
# std                                           3.625383
# min                                          -7.118000
# 25%                                           1.681500
# 50%                                           3.501500
# 75%                                           5.204000
# max                                          22.260000
#
#        Labor force participation rate  \
# count                      364.000000
# mean                        60.417650
# std                         10.857374
# min                         34.070000
# 25%                         53.095000
# 50%                         60.689162
# 75%                         65.944235
# max                         89.790000
#
#        Trade openness: exports plus imports as percent of GDP  \
# count                                         364.000000
# mean                                           75.031806
# std                                            42.328780
# min                                             6.388000
# 25%                                            47.949000
# 50%                                            64.315000
# 75%                                            94.747000
# max                                           341.464000
#
#        Trade balance as percent of GDP  \
# count                       364.000000
# mean                         -4.387188
# std                          12.313603
# min                         -64.598000
# 25%                          -9.553367
# 50%                          -3.716039
# 75%                           1.401825
# max                          42.636000
#
#        Rule of law index (-2.5 weak; 2.5 strong)  \
# count                                 364.000000
# mean                                   -0.378347
# std                                     0.932807
# min                                    -2.374000
# 25%                                    -1.048000
# 50%                                    -0.491000
# 75%                                     0.114167
# max                                     1.990000
#
#        Government effectiveness index (-2.5 weak; 2.5 strong)  \
# count                                         364.000000
# mean                                           -0.335484
# std                                             0.905156
# min                                            -2.110000
# 25%                                            -1.029167
# 50%                                            -0.491000
# 75%                                             0.174500
# max                                             1.990000
#
#        Control of corruption (-2.5 weak; 2.5 strong)  \
# count                                     364.000000
# mean                                       -0.357303
# std                                         0.869489
# min                                        -1.758000
# 25%                                        -1.001000
# 50%                                        -0.535378
# 75%                                        -0.002000
# max                                         2.328000
#
#        Political stability index (-2.5 weak; 2.5 strong)  \
# count                                         364.000000
# mean                                           -0.457010
# std                                             0.970630
# min                                            -2.970000
# 25%                                            -1.134500
# 50%                                            -0.408917
# 75%                                             0.238500
# max                                             1.533333
#
#        Corruption Perceptions Index 100 = no corruption  \
# count                                        364.000000
# mean                                          35.770443
# std                                           17.216801
# min                                            8.000000
# 25%                                           23.600000
# 50%                                           32.400000
# 75%                                           42.684691
# max                                           92.600000
#
#        Political rights index 7 (weak) - 1 (strong)  \
# count                                    364.000000
# mean                                       3.932197
# std                                        2.110785
# min                                        1.000000
# 25%                                        2.000000
# 50%                                        3.946133
# 75%                                        6.000000
# max                                        7.000000
#
#        Access to electricity percent of the population  \
# count                                       364.000000
# mean                                         70.224268
# std                                          35.076287
# min                                         -17.261371
# 25%                                          42.421241
# 50%                                          89.884667
# 75%                                          99.977500
# max                                         108.459339
#
#        Death rate per 1000 people  Economic globalization index (0-100)  \
# count                  364.000000                            364.000000
# mean                     9.252353                             50.579599
# std                      4.285387                             16.360993
# min                      2.330000                             14.332000
# 25%                      6.209000                             37.716500
# 50%                      8.212000                             50.261000
# 75%                     11.607500                             61.721000
# max                     36.970000                             92.328000
#
#        Social globalization index (0-100)  Homicides per 100000 people  \
# count                          364.000000                   364.000000
# mean                            48.909664                     8.319355
# std                             21.573340                     9.672540
# min                              9.886000                    -1.559204
# 25%                             32.423500                     2.555000
# 50%                             50.290000                     6.638548
# 75%                             64.983000                     9.497530
# max                             92.074000                    78.175000
#
#        Group grievance index 0 (low) - 10 (high)      target
# count                                 364.000000  364.000000
# mean                                    6.195628    0.258242
# std                                     1.779150    0.438270
# min                                     1.180000    0.000000
# 25%                                     5.024243    0.000000
# 50%                                     6.317390    0.000000
# 75%                                     7.269343    1.000000
# max                                     9.950000    1.000000

# %% [markdown]
# # Scaler on whole dataset

# %% [markdown]
# Use minmax scaler on the entire dataset

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
imputed_final_df.columns
# Out:
# Index(['Economic growth: the rate of change of real GDP',
#        'Labor force participation rate',
#        'Trade openness: exports plus imports as percent of GDP',
#        'Trade balance as percent of GDP',
#        'Rule of law index (-2.5 weak; 2.5 strong)',
#        'Government effectiveness index (-2.5 weak; 2.5 strong)',
#        'Control of corruption (-2.5 weak; 2.5 strong)',
#        'Political stability index (-2.5 weak; 2.5 strong)',
#        'Corruption Perceptions Index 100 = no corruption',
#        'Political rights index 7 (weak) - 1 (strong)',
#        'Access to electricity percent of the population',
#        'Death rate per 1000 people', 'Economic globalization index (0-100)',
#        'Social globalization index (0-100)', 'Homicides per 100000 people',
#        'Group grievance index 0 (low) - 10 (high)', 'target'],
#       dtype='object')

# %% [markdown]
# # Creating the Model

# %%
model_drops = []

# %%
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
imputed_final_df.drop(columns=model_drops,inplace=True)

scaler = MinMaxScaler()
scaler.fit(imputed_final_df)
full_dataset_scaled = pd.DataFrame(scaler.transform(imputed_final_df), columns=imputed_final_df.columns)


X = full_dataset_scaled.drop(columns='target')
y = full_dataset_scaled['target']
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size = 0.3, random_state=5)

# %%
full_dataset_scaled
# Out:
#      Economic growth: the rate of change of real GDP  \
# 0                                           0.339710
# 1                                           0.351215
# 2                                           0.354891
# 3                                           0.408673
# 4                                           0.083464
# ..                                               ...
# 359                                         0.398870
# 360                                         0.350671
# 361                                         0.319491
# 362                                         0.370754
# 363                                         0.354891
#
#      Labor force participation rate  \
# 0                          0.613761
# 1                          0.563137
# 2                          0.539618
# 3                          0.567835
# 4                          0.570172
# ..                              ...
# 359                        0.631335
# 360                        0.275162
# 361                        0.439375
# 362                        0.535930
# 363                        0.543021
#
#      Trade openness: exports plus imports as percent of GDP  \
# 0                                             0.063096
# 1                                             0.112506
# 2                                             0.033425
# 3                                             0.078466
# 4                                             0.235594
# ..                                                 ...
# 359                                           0.173967
# 360                                           0.150079
# 361                                           0.206204
# 362                                           0.154848
# 363                                           0.033425
#
#      Trade balance as percent of GDP  \
# 0                           0.508234
# 1                           0.493537
# 2                           0.537367
# 3                           0.512226
# 4                           0.575545
# ..                               ...
# 359                         0.557006
# 360                         0.446351
# 361                         0.441073
# 362                         0.620829
# 363                         0.537367
#
#      Rule of law index (-2.5 weak; 2.5 strong)  \
# 0                                     0.229785
# 1                                     0.370820
# 2                                     0.287334
# 3                                     0.309584
# 4                                     0.488353
# ..                                         ...
# 359                                   0.274977
# 360                                   0.493584
# 361                                   0.379468
# 362                                   0.785518
# 363                                   0.297316
#
#      Government effectiveness index (-2.5 weak; 2.5 strong)  \
# 0                                             0.194174
# 1                                             0.304261
# 2                                             0.221805
# 3                                             0.237549
# 4                                             0.466741
# ..                                                 ...
# 359                                           0.393171
# 360                                           0.422927
# 361                                           0.443902
# 362                                           0.837561
# 363                                           0.220560
#
#      Control of corruption (-2.5 weak; 2.5 strong)  \
# 0                                         0.186241
# 1                                         0.253217
# 2                                         0.184520
# 3                                         0.213087
# 4                                         0.380769
# ..                                             ...
# 359                                       0.262849
# 360                                       0.336760
# 361                                       0.313265
# 362                                       0.651493
# 363                                       0.193166
#
#      Political stability index (-2.5 weak; 2.5 strong)  \
# 0                                             0.339652
# 1                                             0.391515
# 2                                             0.314752
# 3                                             0.366125
# 4                                             0.493645
# ..                                                 ...
# 359                                           0.596447
# 360                                           0.612435
# 361                                           0.624426
# 362                                           0.460992
# 363                                           0.378335
#
#      Corruption Perceptions Index 100 = no corruption  \
# 0                                            0.155808
# 1                                            0.233392
# 2                                            0.163768
# 3                                            0.176096
# 4                                            0.408823
# ..                                                ...
# 359                                          0.293144
# 360                                          0.295508
# 361                                          0.335697
# 362                                          0.633570
# 363                                          0.164107
#
#      Political rights index 7 (weak) - 1 (strong)  \
# 0                                        0.708173
# 1                                        0.366667
# 2                                        0.533333
# 3                                        0.366667
# 4                                        0.470586
# ..                                            ...
# 359                                      0.333333
# 360                                      0.233333
# 361                                      0.166667
# 362                                      0.033333
# 363                                      0.533333
#
#      Access to electricity percent of the population  \
# 0                                           0.164469
# 1                                           0.351773
# 2                                           0.300164
# 3                                           0.244275
# 4                                           0.651071
# ..                                               ...
# 359                                         0.865835
# 360                                         0.533145
# 361                                         0.901422
# 362                                         0.932713
# 363                                         0.296619
#
#      Death rate per 1000 people  Economic globalization index (0-100)  \
# 0                      0.507737                              0.073670
# 1                      0.293014                              0.290297
# 2                      0.269400                              0.068029
# 3                      0.349423                              0.046951
# 4                      0.199423                              0.502860
# ..                          ...                                   ...
# 359                    0.130543                              0.399097
# 360                    0.174480                              0.383071
# 361                    0.134353                              0.605980
# 362                    0.081697                              0.719037
# 363                    0.269400                              0.068029
#
#      Social globalization index (0-100)  Homicides per 100000 people  \
# 0                              0.063416                     0.101222
# 1                              0.146931                     0.103153
# 2                              0.037353                     0.107108
# 3                              0.027084                     0.101046
# 4                              0.561210                     0.082263
# ..                                  ...                          ...
# 359                            0.600112                     0.109437
# 360                            0.441987                     0.120190
# 361                            0.659780                     1.000000
# 362                            0.926145                     0.037113
# 363                            0.037353                     0.108112
#
#      Group grievance index 0 (low) - 10 (high)  target
# 0                                     0.752153     1.0
# 1                                     0.672647     1.0
# 2                                     0.755819     1.0
# 3                                     0.716191     1.0
# 4                                     0.595254     1.0
# ..                                         ...     ...
# 359                                   0.576967     0.0
# 360                                   0.530597     0.0
# 361                                   0.586089     0.0
# 362                                   0.994299     0.0
# 363                                   0.667831     0.0
#
# [364 rows x 17 columns]

# %%
bst = XGBClassifier(n_estimators=100,max_depth=30,learning_rate=1, 
                    objective='binary:logistic')

# %%
bst.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=1, max_bin=256,
#               max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#               max_depth=30, max_leaves=0, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=0,
#               num_parallel_tree=1, predictor='auto', random_state=0, ...)

# %%
preds = bst.predict(X_test)

accuracy_score(preds,y_test)
bst.predict_proba(X_test)
print(f'accuracy = {accuracy_score(preds,y_test)}')
print(f'recall = {recall_score(preds,y_test)}')
print(f'f1 = {f1_score(preds,y_test)}')
# Out:
# accuracy = 0.7181818181818181
# recall = 0.5
# f1 = 0.5079365079365079

# %%
import pandas as pd

features = bst.get_booster().feature_names
importances = bst.feature_importances_
feature_importances_df = pd.DataFrame(zip(features, importances), columns=['feature', 'importance']).set_index('feature')
feature_importances_df.sort_values('importance', ascending=False).head(20).keys
# Out:
# <bound method NDFrame.keys of                                                     importance
# feature
# Group grievance index 0 (low) - 10 (high)             0.258598
# Political stability index (-2.5 weak; 2.5 strong)     0.114760
# Corruption Perceptions Index 100 = no corruption      0.080582
# Government effectiveness index (-2.5 weak; 2.5 ...    0.070241
# Trade balance as percent of GDP                       0.060898
# Homicides per 100000 people                           0.059430
# Rule of law index (-2.5 weak; 2.5 strong)             0.057771
# Economic globalization index (0-100)                  0.054578
# Political rights index 7 (weak) - 1 (strong)          0.043711
# Death rate per 1000 people                            0.040445
# Labor force participation rate                        0.037075
# Control of corruption (-2.5 weak; 2.5 strong)         0.035238
# Social globalization index (0-100)                    0.030321
# Trade openness: exports plus imports as percent...    0.024354
# Economic growth: the rate of change of real GDP       0.018153
# Access to electricity percent of the population       0.013843>

# %%
feature_importances_df.sort_values('importance', ascending=False).tail(20)
# Out:
#                                                     importance
# feature
# Group grievance index 0 (low) - 10 (high)             0.258598
# Political stability index (-2.5 weak; 2.5 strong)     0.114760
# Corruption Perceptions Index 100 = no corruption      0.080582
# Government effectiveness index (-2.5 weak; 2.5 ...    0.070241
# Trade balance as percent of GDP                       0.060898
# Homicides per 100000 people                           0.059430
# Rule of law index (-2.5 weak; 2.5 strong)             0.057771
# Economic globalization index (0-100)                  0.054578
# Political rights index 7 (weak) - 1 (strong)          0.043711
# Death rate per 1000 people                            0.040445
# Labor force participation rate                        0.037075
# Control of corruption (-2.5 weak; 2.5 strong)         0.035238
# Social globalization index (0-100)                    0.030321
# Trade openness: exports plus imports as percent...    0.024354
# Economic growth: the rate of change of real GDP       0.018153
# Access to electricity percent of the population       0.013843

# %%
def get_imputed_df(country,year,lookback=5):
    df = get_hist_data(country,year,lookback).groupby('country_all').mean(numeric_only=True)
    df.drop(columns=[col for col in df if col not in columns_to_keep],inplace=True)
    df['target'] = 0.5
    imputed_df = pd.DataFrame(imputer.transform(df),columns=df.columns)
    imputed_df.drop(columns=model_drops,inplace=True)
    
    
    return imputed_df




def get_prob(country,year,lookback=5):
    df = get_imputed_df(country,year,lookback)
    scaled_df = pd.DataFrame(scaler.transform(df),columns=df.columns)
    scaled_df.drop(columns='target',inplace=True)
    prob = bst.predict_proba(scaled_df)[0][1]
    return prob

def prob_series(country,start_year,end_year,lookback=5):
    my_list =[]
    for year in range(start_year,end_year+1):
        my_list.append(get_prob(country,year,lookback))
    return my_list


    
prob_series('USA',1990,2020)
get_imputed_df('Iran',2019)
# Out:
#    Economic growth: the rate of change of real GDP  \
# 0                                            2.578
#
#    Labor force participation rate  \
# 0                          42.388
#
#    Trade openness: exports plus imports as percent of GDP  \
# 0                                             45.656
#
#    Trade balance as percent of GDP  Rule of law index (-2.5 weak; 2.5 strong)  \
# 0                             0.61                                     -0.808
#
#    Government effectiveness index (-2.5 weak; 2.5 strong)  \
# 0                                             -0.292
#
#    Control of corruption (-2.5 weak; 2.5 strong)  \
# 0                                         -0.748
#
#    Political stability index (-2.5 weak; 2.5 strong)  \
# 0                                             -0.978
#
#    Corruption Perceptions Index 100 = no corruption  \
# 0                                              28.2
#
#    Political rights index 7 (weak) - 1 (strong)  \
# 0                                           6.0
#
#    Access to electricity percent of the population  \
# 0                                            99.97
#
#    Death rate per 1000 people  Economic globalization index (0-100)  \
# 0                        4.82                                 26.86
#
#    Social globalization index (0-100)  Homicides per 100000 people  \
# 0                              57.082                          3.3
#
#    Group grievance index 0 (low) - 10 (high)  target
# 0                                       8.94     0.5

# %%
def plot_prob_series(country,start_year,end_year,lookback=5):
    
    sns.lineplot(x = list(range(start_year,end_year+1)),y=prob_series(country,start_year,end_year,lookback))
    
#plot_prob_series('Mexico',1990,2022)

# %%
codes = pd.read_csv('/Users/yasmeenmahomedy2/Downloads/Conflict Datasets/country_code_example.csv')


def lambda_prob(row):
    
    prob_value = get_prob(row['Country from our model'],2021)
    
    return prob_value

code_dict = pd.Series(codes['Country from our model'].values,index=codes.Code).to_dict()

codes2 = codes[['Country from our model', 'Code']].dropna()

codes2['prob'] = codes2.apply(lambda x: lambda_prob(x),axis=1)
# codes2
# codes2['next_year_prob'] = get_prob(codes2['Country from our model'],2022)

codes2 = codes[['Country from our model', 'Code']].dropna()
code_dict_2 = dict(zip(code_dict.values(),code_dict.keys()))
code_dict_2['USA'] = 'USA'
code_dict_2['Uruguay'] = 'URY'

# %%
def get_year_probs(year):
    def lambda_prob(row):
    
        prob_value = get_prob(row['Country from our model'],year)
    
        return prob_value
    codes3 = codes[['Country from our model', 'Code']].dropna()
    
    codes3[year] = codes3.apply(lambda x: lambda_prob(x),axis=1)
    return codes3

get_year_probs(1990)

time_series_probs = [get_year_probs(i) for i in range(1990,2023)]

# %%
time_series_large = time_series_probs[0]

for i in range(1,len(time_series_probs)):
    time_series_large = pd.merge(time_series_large,time_series_probs[i],on=['Country from our model','Code'])

# %%
time_series_large
# Out:
#     Country from our model Code      1990      1991      1992      1993  \
# 0              Afghanistan  AFG  0.803428  0.906573  0.925497  0.914452
# 1                  Albania  ALB  0.988803  0.938125  0.573972  0.864048
# 2                  Algeria  DZA  0.954389  0.978439  0.990014  0.991417
# 3                   Angola  AGO  0.224448  0.000236  0.000304  0.000250
# 4                Argentina  ARG  0.606313  0.125165  0.125165  0.261753
# ..                     ...  ...       ...       ...       ...       ...
# 170              Venezuela  VEN  0.134444  0.155053  0.014423  0.017122
# 171                Vietnam  VNM  0.942864  0.945741  0.797755  0.748997
# 172                  Yemen  YEM  0.001068  0.723755  0.758464  0.777537
# 173                 Zambia  ZMB  0.062127  0.031845  0.099673  0.065215
# 174               Zimbabwe  ZWE  0.860752  0.937792  0.838360  0.907073
#
#          1994      1995      1996      1997  ...      2013      2014  \
# 0    0.906573  0.904505  0.776539  0.920187  ...  0.212551  0.049097
# 1    0.052387  0.001792  0.001217  0.000238  ...  0.000277  0.000393
# 2    0.996883  0.996500  0.984383  0.995519  ...  0.006306  0.005049
# 3    0.000906  0.001162  0.000568  0.352562  ...  0.831216  0.822317
# 4    0.082305  0.006665  0.011316  0.004371  ...  0.000381  0.003286
# ..        ...       ...       ...       ...  ...       ...       ...
# 170  0.005869  0.007468  0.009487  0.008804  ...  0.427496  0.975515
# 171  0.508699  0.191110  0.489074  0.095609  ...  0.686233  0.764748
# 172  0.027762  0.009539  0.011013  0.097371  ...  0.903587  0.819794
# 173  0.029256  0.046038  0.013899  0.001499  ...  0.009892  0.012428
# 174  0.965397  0.873530  0.649543  0.077585  ...  0.828747  0.910620
#
#          2015      2016      2017      2018      2019      2020      2021  \
# 0    0.980907  0.510171  0.268328  0.037876  0.067701  0.024761  0.989497
# 1    0.000821  0.004818  0.008717  0.098508  0.022776  0.022776  0.056114
# 2    0.004731  0.101460  0.182110  0.034197  0.035551  0.119253  0.605704
# 3    0.703294  0.775039  0.685476  0.970688  0.912779  0.945668  0.420565
# 4    0.000129  0.002249  0.009725  0.011757  0.003484  0.027183  0.004767
# ..        ...       ...       ...       ...       ...       ...       ...
# 170  0.813636  0.022156  0.052082  0.013374  0.052972  0.035616  0.036873
# 171  0.835101  0.835101  0.131899  0.036296  0.154087  0.170828  0.170828
# 172  0.509853  0.864743  0.456908  0.218941  0.037049  0.030499  0.044107
# 173  0.013876  0.025300  0.019061  0.008496  0.010010  0.007470  0.597735
# 174  0.952775  0.954155  0.939280  0.870471  0.710554  0.412313  0.115057
#
#          2022
# 0    0.959587
# 1    0.057035
# 2    0.460346
# 3    0.148218
# 4    0.007835
# ..        ...
# 170  0.282176
# 171  0.158105
# 172  0.072547
# 173  0.437200
# 174  0.296907
#
# [175 rows x 35 columns]

# %%
time_series_probs[10]
# Out:
#     Country from our model Code      2000
# 0              Afghanistan  AFG  0.741617
# 1                  Albania  ALB  0.000126
# 2                  Algeria  DZA  0.997183
# 3                   Angola  AGO  0.882322
# 4                Argentina  ARG  0.047743
# ..                     ...  ...       ...
# 170              Venezuela  VEN  0.011720
# 171                Vietnam  VNM  0.006536
# 172                  Yemen  YEM  0.096277
# 173                 Zambia  ZMB  0.001354
# 174               Zimbabwe  ZWE  0.124663
#
# [175 rows x 3 columns]

# %%
def plot_feature_series(country,feature,lookback=5):
    years = list(range(1990,2023))
    series = [get_imputed_df(country, i, lookback)[feature][0] for i in years]
    return sns.lineplot(x=years,y=series)


#plot_feature_series('Iran','Control of corruption (-2.5 weak; 2.5 strong)')

# %% [markdown]
# # Downloading the data

# %%
csv_full['year_all'] = csv_full.apply(lambda x: get_year(x),axis=1)

# %%
codes2.head()
# Out:
#   Country from our model Code
# 0            Afghanistan  AFG
# 1                Albania  ALB
# 2                Algeria  DZA
# 3                 Angola  AGO
# 4              Argentina  ARG

# %%
list_of_full_dfs = []

for country in codes2['Country from our model']:
    df = get_imputed_df(country,1990) 
    df['country'] = country
    df['year'] = 1990
    list_of_full_dfs.append(df)

# %%
list_of_fuller_dfs = []

# %%
for df in list_of_full_dfs:
    
    country = df['country'][0]
    for year in range(1991,2023):
        new_year_df = get_imputed_df(country,year)
        new_year_df['country'] = country
        new_year_df['year'] = year
        
        df = pd.concat([df,new_year_df])
        
    list_of_fuller_dfs.append(df)

# %%
monster_df= list_of_fuller_dfs[0]

for i in range(1,len(list_of_fuller_dfs)):
    monster_df = pd.concat([monster_df,list_of_fuller_dfs[i]])

# %%
list_of_full_dfs[1]
# Out:
#    Economic growth: the rate of change of real GDP  \
# 0                                             3.01
#
#    Labor force participation rate  \
# 0                       57.147526
#
#    Trade openness: exports plus imports as percent of GDP  \
# 0                                              35.34
#
#    Trade balance as percent of GDP  Rule of law index (-2.5 weak; 2.5 strong)  \
# 0                           -1.726                                  -1.235113
#
#    Government effectiveness index (-2.5 weak; 2.5 strong)  \
# 0                                          -1.128261
#
#    Control of corruption (-2.5 weak; 2.5 strong)  \
# 0                                      -1.065362
#
#    Political stability index (-2.5 weak; 2.5 strong)  \
# 0                                          -1.345141
#
#    Corruption Perceptions Index 100 = no corruption  \
# 0                                         22.401866
#
#    Political rights index 7 (weak) - 1 (strong)  \
# 0                                           7.0
#
#    Access to electricity percent of the population  \
# 0                                        61.432836
#
#    Death rate per 1000 people  Economic globalization index (0-100)  \
# 0                       5.876                                23.976
#
#    Social globalization index (0-100)  Homicides per 100000 people  \
# 0                              32.206                    10.032213
#
#    Group grievance index 0 (low) - 10 (high)  target  country  year
# 0                                   7.870577     0.5  Albania  1990

# %%
def get_year(row):
    
    year_value = row['CountryYear'][-4:]
    
    return int(year_value)

# %%
master_df.head()

def prob_for_master_df(row):
    
    prob = get_prob(row['country'],row['year'])
    
    return prob

master_df['prob'] = master_df.apply(lambda x: prob_for_master_df(x),axis=1)

# %%
master_df['code'] = master_df['country'].map(code_dict_2)

# %%
master_df.to_csv('full_feature_test_new.csv')
